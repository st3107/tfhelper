# %% [markdown]
# # Run logistic regression on fraction labels
#
# Run the logistic regression as the first model for the project. It will be used to compare with the deep learning model.

# %% [markdown]
# ## Import necessary modules

# %%
# python built-in libraries
import datetime

# %%
# choose the tensorflow log level
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}

# %%
# import tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# ohter packages
import numpy as np

import tfhelper.core as tfhelper

# %% [markdown]
# ## Global Variables

# %%
# sampling
FEATURES_FILE = "./data/tensors/features_continous.npy"  # path to the file of the feature tensor
LABELS_FILE = "./data/tensors/labels_continous.npy"  # path to the file of the feature tensor
FRACTIONS = (0.8, 0.1, 0.1)  # train, validation, test
BATCH_SIZE = 256  # size of the batch
BUFFER_SIZE = BATCH_SIZE * 2  # size of the shuffle buffer
# training
LEARNING_RATE = 0.001  # starting learning rate
BETA1 = 0.9  # decay 1
BETA2 = 0.999  # decay 2
EPOCHS = 200  # number of epochs
# saving
TIME_STAMP = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  # time stamp
SAVE_LOC = "./data/models/lr_{}".format(TIME_STAMP)  # path to the folder to save the model
LOG_LOC = "./data/logs/fit/lr_{}".format(TIME_STAMP)  # path to the log, if you change this, you also need to change it in the run_tensorboard

# %% [markdown]
# ## Obtain data
#
# The data is a 209 data point PDF. The label is a one-hot 2 dim vector. `10` means major phase >= threshold, `01` means major phase <= threshold.

# %%
def load_data():
    # load
    features, labels = np.load(FEATURES_FILE), np.load(LABELS_FILE)
    # sort the labels
    labels = np.sort(labels, axis=1)[:, ::-1]
    # shuffle
    n = features.shape[0]
    shuffled_idx = np.random.permutation(n)
    features, labels = features[shuffled_idx], labels[shuffled_idx]
    # split
    f0, f1, f2 = FRACTIONS
    i, j, k = round(f0 * n), round((f0 + f1) * n), round((f0 + f1 + f2) * n)
    train_data = tf.data.Dataset.from_tensor_slices((features[:i], labels[:i])).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
    valid_data = tf.data.Dataset.from_tensor_slices((features[i:j], labels[i:j])).batch(BATCH_SIZE)
    test_data = tf.data.Dataset.from_tensor_slices((features[j:k], labels[j:k])).batch(BATCH_SIZE)
    return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data()

# %% [markdown]
# ## Create the model
#
# We use the logistric regression. It is a single layer with a softmax function.

# %%
def create_model():
    model = keras.Sequential()
    model.add(keras.Input(shape=(209,)))
    model.add(layers.Dense(2, activation="softmax"))
    return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2)                 420
# =================================================================
# Total params: 420
# Trainable params: 420
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Choose optimization method

# %%
model.compile(
    # Optimizer
    optimizer=keras.optimizers.Adam(LEARNING_RATE, BETA1, BETA2),
    # Loss function to minimize
    loss=keras.losses.MeanSquaredError(),
    # List of metrics to monitor
    metrics=[
        keras.metrics.CosineSimilarity()
    ],
)

# %% [markdown]
# ## Train the model

# %%
# tensor board
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=LOG_LOC, histogram_freq=1)

# %%
# early stopping to avoid over fitting
earlystopping_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=50, 
    restore_best_weights=True
)

# %%
history = model.fit(
    x=train_data,
    epochs=EPOCHS,
    callbacks=[
        tensorboard_callback,
        earlystopping_callback
    ],
    validation_data=valid_data
)
# Out:
# Epoch 1/200
# 344/344 [==============================] - 10s 21ms/step - loss: 0.0312 - cosine_similarity: 0.9631 - val_loss: 0.0291 - val_cosine_similarity: 0.9653
# Epoch 2/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0291 - cosine_similarity: 0.9657 - val_loss: 0.0285 - val_cosine_similarity: 0.9666
# Epoch 3/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0287 - cosine_similarity: 0.9662 - val_loss: 0.0285 - val_cosine_similarity: 0.9657
# Epoch 4/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0285 - cosine_similarity: 0.9664 - val_loss: 0.0281 - val_cosine_similarity: 0.9665
# Epoch 5/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0283 - cosine_similarity: 0.9666 - val_loss: 0.0280 - val_cosine_similarity: 0.9665
# Epoch 6/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0282 - cosine_similarity: 0.9667 - val_loss: 0.0281 - val_cosine_similarity: 0.9662
# Epoch 7/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0281 - cosine_similarity: 0.9668 - val_loss: 0.0278 - val_cosine_similarity: 0.9668
# Epoch 8/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0281 - cosine_similarity: 0.9668 - val_loss: 0.0277 - val_cosine_similarity: 0.9673
# Epoch 9/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0280 - cosine_similarity: 0.9670 - val_loss: 0.0279 - val_cosine_similarity: 0.9663
# Epoch 10/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0279 - cosine_similarity: 0.9670 - val_loss: 0.0278 - val_cosine_similarity: 0.9665
# Epoch 11/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0279 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9672
# Epoch 12/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0277 - val_cosine_similarity: 0.9678
# Epoch 13/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9676
# Epoch 14/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0279 - val_cosine_similarity: 0.9662
# Epoch 15/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9670 - val_loss: 0.0279 - val_cosine_similarity: 0.9663
# Epoch 16/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 17/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 18/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 19/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 20/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 21/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9665
# Epoch 22/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0278 - val_cosine_similarity: 0.9663
# Epoch 23/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9671
# Epoch 24/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 25/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 26/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9667
# Epoch 27/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 28/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 29/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 30/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 31/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9666
# Epoch 32/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 33/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 34/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 35/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9678
# Epoch 36/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 37/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 38/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 39/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 40/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9670
# Epoch 41/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 42/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 43/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 44/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 45/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 46/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 47/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9678
# Epoch 48/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 49/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0279 - val_cosine_similarity: 0.9661
# Epoch 50/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 51/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 52/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 53/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 54/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 55/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 56/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9666
# Epoch 57/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 58/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 59/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 60/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 61/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 62/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 63/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 64/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 65/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 66/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9663
# Epoch 67/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 68/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 69/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 70/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 71/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 72/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 73/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9670
# Epoch 74/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 75/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 76/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 77/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 78/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 79/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 80/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 81/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 82/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 83/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 84/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 85/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 86/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 87/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9667
# Epoch 88/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 89/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 90/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 91/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0279 - val_cosine_similarity: 0.9662
# Epoch 92/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 93/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0279 - val_cosine_similarity: 0.9662
# Epoch 94/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 95/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 96/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 97/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 98/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 99/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 100/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9663
# Epoch 101/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 102/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 103/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 104/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 105/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9665
# Epoch 106/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 107/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 108/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 109/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 110/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9667
# Epoch 111/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 112/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 113/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 114/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 115/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0278 - val_cosine_similarity: 0.9664
# Epoch 116/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 117/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 118/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 119/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 120/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 121/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 122/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 123/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 124/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 125/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9666
# Epoch 126/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9666
# Epoch 127/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 128/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 129/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 130/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 131/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 132/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 133/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 134/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9663
# Epoch 135/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 136/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 137/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 138/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 139/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9667
# Epoch 140/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0277 - val_cosine_similarity: 0.9667
# Epoch 141/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 142/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 143/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 144/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9670
# Epoch 145/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 146/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 147/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 148/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 149/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 150/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 151/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 152/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 153/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 154/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 155/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9667
# Epoch 156/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 157/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 158/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 159/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 160/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 161/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 162/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9675
# Epoch 163/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 164/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 165/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 166/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 167/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 168/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 169/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 170/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 171/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 172/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 173/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9663
# Epoch 174/200
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0277 - val_cosine_similarity: 0.9666
# Epoch 175/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 176/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 177/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 178/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 179/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9667
# Epoch 180/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9671 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 181/200
# 344/344 [==============================] - 2s 6ms/step - loss: 0.0276 - cosine_similarity: 0.9673 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 182/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0280 - val_cosine_similarity: 0.9660
# Epoch 183/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 184/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 185/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0278 - val_cosine_similarity: 0.9662
# Epoch 186/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 187/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 188/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9674
# Epoch 189/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 190/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9669
# Epoch 191/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 192/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9676
# Epoch 193/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9672
# Epoch 194/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9670
# Epoch 195/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0276 - val_cosine_similarity: 0.9668
# Epoch 196/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 197/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9671
# Epoch 198/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9677
# Epoch 199/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9672 - val_loss: 0.0275 - val_cosine_similarity: 0.9673
# Epoch 200/200
# 344/344 [==============================] - 2s 5ms/step - loss: 0.0277 - cosine_similarity: 0.9673 - val_loss: 0.0275 - val_cosine_similarity: 0.9673

# %% [markdown]
# ## Evaluate the model

# %%
result = model.evaluate(
    x=test_data,
    return_dict=True
)
# Out:
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0277 - cosine_similarity: 0.9668

# %%
for name, val in result.items():
    print("{:20s} {:.4f}".format(name, val))
# Out:
# loss                 0.0277
# cosine_similarity    0.9668

# %% [markdown]
# ## Save the model

# %%
model.save(SAVE_LOC)
# Out:
# INFO:tensorflow:Assets written to: ./data/models/lr_20210914-153328/assets
