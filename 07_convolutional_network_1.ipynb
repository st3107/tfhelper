# %% [markdown]
# # Test the full connected layer model

# %% [markdown]
# ## Import necessary modules

# %%
# python built-in libraries
import datetime

# %%
# choose the tensorflow log level
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}

# %%
# import tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# ohter packages
import numpy as np

import tfhelper.core as tfhelper

# %% [markdown]
# ## Global Variables

# %%
# sampling
FEATURES_FILE = "./data/tensors/features_continous.npy"  # path to the file of the feature tensor
LABELS_FILE = "./data/tensors/labels_continous.npy"  # path to the file of the feature tensor
FRACTIONS = (0.8, 0.1, 0.1)  # train, validation, test
BATCH_SIZE = 256  # size of the batch
BUFFER_SIZE = BATCH_SIZE * 2  # size of the shuffle buffer
# training
LEARNING_RATE = 0.001  # starting learning rate
BETA1 = 0.9  # decay 1
BETA2 = 0.999  # decay 2
EPOCHS = 200  # number of epochs
# saving
TIME_STAMP = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")  # time stamp
SAVE_LOC = "./data/models/cnn_1_{}".format(TIME_STAMP)  # path to the folder to save the model
LOG_LOC = "./data/logs/fit/cnn_1_{}".format(TIME_STAMP)  # path to the log, if you change this, you also need to change it in the run_tensorboard

# %% [markdown]
# ## Obtain data
#
# The data is a 209 data point PDF. The label is a one-hot 2 dim vector. `10` means major phase >= threshold, `01` means major phase <= threshold.

# %%
def load_data():
    # load
    features, labels = np.load(FEATURES_FILE), np.load(LABELS_FILE)
    # sort the labels
    labels = np.sort(labels, axis=1)[:, ::-1]
    # shuffle
    n = features.shape[0]
    shuffled_idx = np.random.permutation(n)
    features, labels = features[shuffled_idx], labels[shuffled_idx]
    # split
    f0, f1, f2 = FRACTIONS
    i, j, k = round(f0 * n), round((f0 + f1) * n), round((f0 + f1 + f2) * n)
    train_data = tf.data.Dataset.from_tensor_slices((features[:i], labels[:i])).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
    valid_data = tf.data.Dataset.from_tensor_slices((features[i:j], labels[i:j])).batch(BATCH_SIZE)
    test_data = tf.data.Dataset.from_tensor_slices((features[j:k], labels[j:k])).batch(BATCH_SIZE)
    return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data()

# %% [markdown]
# ## Create the model
#
# We use the logistric regression. It is a single layer with a softmax function.

# %%
def create_model():
    model = keras.Sequential()
    model.add(keras.Input(shape=(209,)))
    model.add(keras.layers.Reshape((209, 1)))
    model.add(keras.layers.Conv1D(16, 32, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.Conv1D(16, 32, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.MaxPooling1D(4))
    model.add(keras.layers.Conv1D(64, 16, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.Conv1D(64, 16, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.MaxPooling1D(4))
    model.add(keras.layers.Conv1D(256, 8, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.Conv1D(256, 8, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.MaxPooling1D(2))
    model.add(keras.layers.Conv1D(512, 4, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.Conv1D(512, 4, strides=1, activation='relu', padding="same"))
    model.add(keras.layers.MaxPooling1D(2))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(2, activation='softmax'))
    return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 209, 1)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 209, 16)           528
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 209, 16)           8208
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 52, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 52, 64)            16448
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 52, 64)            65600
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 13, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 13, 256)           131328
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 13, 256)           524544
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 6, 256)            0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 6, 512)            524800
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 6, 512)            1049088
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 3, 512)            0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 2,321,570
# Trainable params: 2,321,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Choose optimization method

# %%
model.compile(
    # Optimizer
    optimizer=keras.optimizers.Adam(LEARNING_RATE, BETA1, BETA2),
    # Loss function to minimize
    loss=keras.losses.MeanSquaredError(),
    # List of metrics to monitor
    metrics=[
        keras.metrics.CosineSimilarity()
    ],
)

# %% [markdown]
# ## Train the model

# %%
# tensor board
tensorboard_callback = keras.callbacks.TensorBoard(
    log_dir=LOG_LOC, 
    histogram_freq=1
)

# %%
# early stopping to avoid over fitting
earlystopping_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=50, 
    restore_best_weights=True
)

# %%
history = model.fit(
    x=train_data,
    epochs=EPOCHS,
    callbacks=[
        tensorboard_callback,
        earlystopping_callback
    ],
    validation_data=valid_data
)
# Out:
# Epoch 1/200
# 344/344 [==============================] - 76s 74ms/step - loss: 0.0376 - cosine_similarity: 0.9569 - val_loss: 0.0284 - val_cosine_similarity: 0.9659
# Epoch 2/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0282 - cosine_similarity: 0.9666 - val_loss: 0.0279 - val_cosine_similarity: 0.9672
# Epoch 3/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0278 - cosine_similarity: 0.9671 - val_loss: 0.0274 - val_cosine_similarity: 0.9674
# Epoch 4/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0273 - cosine_similarity: 0.9677 - val_loss: 0.0272 - val_cosine_similarity: 0.9679
# Epoch 5/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0267 - cosine_similarity: 0.9683 - val_loss: 0.0268 - val_cosine_similarity: 0.9676
# Epoch 6/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0259 - cosine_similarity: 0.9692 - val_loss: 0.0268 - val_cosine_similarity: 0.9668
# Epoch 7/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0245 - cosine_similarity: 0.9707 - val_loss: 0.0252 - val_cosine_similarity: 0.9694
# Epoch 8/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0228 - cosine_similarity: 0.9726 - val_loss: 0.0239 - val_cosine_similarity: 0.9709
# Epoch 9/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0216 - cosine_similarity: 0.9741 - val_loss: 0.0249 - val_cosine_similarity: 0.9692
# Epoch 10/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0204 - cosine_similarity: 0.9754 - val_loss: 0.0234 - val_cosine_similarity: 0.9721
# Epoch 11/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0194 - cosine_similarity: 0.9765 - val_loss: 0.0225 - val_cosine_similarity: 0.9724
# Epoch 12/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0186 - cosine_similarity: 0.9774 - val_loss: 0.0226 - val_cosine_similarity: 0.9726
# Epoch 13/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0183 - cosine_similarity: 0.9778 - val_loss: 0.0224 - val_cosine_similarity: 0.9733
# Epoch 14/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0175 - cosine_similarity: 0.9787 - val_loss: 0.0221 - val_cosine_similarity: 0.9733
# Epoch 15/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0172 - cosine_similarity: 0.9791 - val_loss: 0.0224 - val_cosine_similarity: 0.9729
# Epoch 16/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0167 - cosine_similarity: 0.9796 - val_loss: 0.0228 - val_cosine_similarity: 0.9722
# Epoch 17/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0164 - cosine_similarity: 0.9801 - val_loss: 0.0219 - val_cosine_similarity: 0.9737
# Epoch 18/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0160 - cosine_similarity: 0.9805 - val_loss: 0.0224 - val_cosine_similarity: 0.9728
# Epoch 19/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0155 - cosine_similarity: 0.9811 - val_loss: 0.0230 - val_cosine_similarity: 0.9716
# Epoch 20/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0152 - cosine_similarity: 0.9815 - val_loss: 0.0233 - val_cosine_similarity: 0.9721
# Epoch 21/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0149 - cosine_similarity: 0.9818 - val_loss: 0.0226 - val_cosine_similarity: 0.9728
# Epoch 22/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0145 - cosine_similarity: 0.9824 - val_loss: 0.0217 - val_cosine_similarity: 0.9736
# Epoch 23/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0143 - cosine_similarity: 0.9827 - val_loss: 0.0206 - val_cosine_similarity: 0.9747
# Epoch 24/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0142 - cosine_similarity: 0.9828 - val_loss: 0.0208 - val_cosine_similarity: 0.9746
# Epoch 25/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0140 - cosine_similarity: 0.9829 - val_loss: 0.0211 - val_cosine_similarity: 0.9740
# Epoch 26/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0137 - cosine_similarity: 0.9833 - val_loss: 0.0226 - val_cosine_similarity: 0.9730
# Epoch 27/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0135 - cosine_similarity: 0.9836 - val_loss: 0.0210 - val_cosine_similarity: 0.9744
# Epoch 28/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0132 - cosine_similarity: 0.9840 - val_loss: 0.0206 - val_cosine_similarity: 0.9749
# Epoch 29/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0130 - cosine_similarity: 0.9843 - val_loss: 0.0207 - val_cosine_similarity: 0.9750
# Epoch 30/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0128 - cosine_similarity: 0.9845 - val_loss: 0.0194 - val_cosine_similarity: 0.9764
# Epoch 31/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0128 - cosine_similarity: 0.9845 - val_loss: 0.0198 - val_cosine_similarity: 0.9761
# Epoch 32/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0128 - cosine_similarity: 0.9845 - val_loss: 0.0197 - val_cosine_similarity: 0.9760
# Epoch 33/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0124 - cosine_similarity: 0.9850 - val_loss: 0.0195 - val_cosine_similarity: 0.9762
# Epoch 34/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0121 - cosine_similarity: 0.9854 - val_loss: 0.0198 - val_cosine_similarity: 0.9759
# Epoch 35/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0120 - cosine_similarity: 0.9855 - val_loss: 0.0200 - val_cosine_similarity: 0.9754
# Epoch 36/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0117 - cosine_similarity: 0.9858 - val_loss: 0.0214 - val_cosine_similarity: 0.9739
# Epoch 37/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0119 - cosine_similarity: 0.9857 - val_loss: 0.0211 - val_cosine_similarity: 0.9743
# Epoch 38/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0118 - cosine_similarity: 0.9858 - val_loss: 0.0210 - val_cosine_similarity: 0.9742
# Epoch 39/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0117 - cosine_similarity: 0.9859 - val_loss: 0.0201 - val_cosine_similarity: 0.9752
# Epoch 40/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0116 - cosine_similarity: 0.9860 - val_loss: 0.0201 - val_cosine_similarity: 0.9754
# Epoch 41/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0114 - cosine_similarity: 0.9862 - val_loss: 0.0192 - val_cosine_similarity: 0.9765
# Epoch 42/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0112 - cosine_similarity: 0.9864 - val_loss: 0.0190 - val_cosine_similarity: 0.9766
# Epoch 43/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0111 - cosine_similarity: 0.9866 - val_loss: 0.0193 - val_cosine_similarity: 0.9766
# Epoch 44/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0113 - cosine_similarity: 0.9863 - val_loss: 0.0194 - val_cosine_similarity: 0.9763
# Epoch 45/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0111 - cosine_similarity: 0.9866 - val_loss: 0.0185 - val_cosine_similarity: 0.9772
# Epoch 46/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0109 - cosine_similarity: 0.9868 - val_loss: 0.0196 - val_cosine_similarity: 0.9759
# Epoch 47/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0108 - cosine_similarity: 0.9869 - val_loss: 0.0201 - val_cosine_similarity: 0.9754
# Epoch 48/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0107 - cosine_similarity: 0.9870 - val_loss: 0.0199 - val_cosine_similarity: 0.9758
# Epoch 49/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0106 - cosine_similarity: 0.9872 - val_loss: 0.0195 - val_cosine_similarity: 0.9762
# Epoch 50/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0103 - cosine_similarity: 0.9876 - val_loss: 0.0196 - val_cosine_similarity: 0.9760
# Epoch 51/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0103 - cosine_similarity: 0.9876 - val_loss: 0.0199 - val_cosine_similarity: 0.9756
# Epoch 52/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0102 - cosine_similarity: 0.9877 - val_loss: 0.0187 - val_cosine_similarity: 0.9772
# Epoch 53/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0101 - cosine_similarity: 0.9878 - val_loss: 0.0190 - val_cosine_similarity: 0.9768
# Epoch 54/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0101 - cosine_similarity: 0.9878 - val_loss: 0.0193 - val_cosine_similarity: 0.9763
# Epoch 55/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0102 - cosine_similarity: 0.9878 - val_loss: 0.0192 - val_cosine_similarity: 0.9767
# Epoch 56/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0102 - cosine_similarity: 0.9877 - val_loss: 0.0189 - val_cosine_similarity: 0.9771
# Epoch 57/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0100 - cosine_similarity: 0.9879 - val_loss: 0.0190 - val_cosine_similarity: 0.9773
# Epoch 58/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0100 - cosine_similarity: 0.9880 - val_loss: 0.0185 - val_cosine_similarity: 0.9777
# Epoch 59/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0101 - cosine_similarity: 0.9879 - val_loss: 0.0192 - val_cosine_similarity: 0.9770
# Epoch 60/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0100 - cosine_similarity: 0.9879 - val_loss: 0.0192 - val_cosine_similarity: 0.9766
# Epoch 61/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0099 - cosine_similarity: 0.9881 - val_loss: 0.0192 - val_cosine_similarity: 0.9765
# Epoch 62/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0099 - cosine_similarity: 0.9881 - val_loss: 0.0195 - val_cosine_similarity: 0.9762
# Epoch 63/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0100 - cosine_similarity: 0.9880 - val_loss: 0.0196 - val_cosine_similarity: 0.9759
# Epoch 64/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0099 - cosine_similarity: 0.9880 - val_loss: 0.0187 - val_cosine_similarity: 0.9772
# Epoch 65/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0099 - cosine_similarity: 0.9881 - val_loss: 0.0185 - val_cosine_similarity: 0.9775
# Epoch 66/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0097 - cosine_similarity: 0.9882 - val_loss: 0.0185 - val_cosine_similarity: 0.9772
# Epoch 67/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0099 - cosine_similarity: 0.9881 - val_loss: 0.0179 - val_cosine_similarity: 0.9780
# Epoch 68/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0097 - cosine_similarity: 0.9883 - val_loss: 0.0175 - val_cosine_similarity: 0.9786
# Epoch 69/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0096 - cosine_similarity: 0.9884 - val_loss: 0.0179 - val_cosine_similarity: 0.9782
# Epoch 70/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0094 - cosine_similarity: 0.9886 - val_loss: 0.0187 - val_cosine_similarity: 0.9768
# Epoch 71/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0093 - cosine_similarity: 0.9888 - val_loss: 0.0184 - val_cosine_similarity: 0.9773
# Epoch 72/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0092 - cosine_similarity: 0.9889 - val_loss: 0.0184 - val_cosine_similarity: 0.9775
# Epoch 73/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0093 - cosine_similarity: 0.9887 - val_loss: 0.0190 - val_cosine_similarity: 0.9767
# Epoch 74/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0095 - cosine_similarity: 0.9885 - val_loss: 0.0192 - val_cosine_similarity: 0.9765
# Epoch 75/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0097 - cosine_similarity: 0.9883 - val_loss: 0.0182 - val_cosine_similarity: 0.9778
# Epoch 76/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0096 - cosine_similarity: 0.9883 - val_loss: 0.0187 - val_cosine_similarity: 0.9772
# Epoch 77/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0095 - cosine_similarity: 0.9885 - val_loss: 0.0192 - val_cosine_similarity: 0.9765
# Epoch 78/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0095 - cosine_similarity: 0.9886 - val_loss: 0.0184 - val_cosine_similarity: 0.9774
# Epoch 79/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0092 - cosine_similarity: 0.9889 - val_loss: 0.0177 - val_cosine_similarity: 0.9783
# Epoch 80/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0093 - cosine_similarity: 0.9889 - val_loss: 0.0179 - val_cosine_similarity: 0.9781
# Epoch 81/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0091 - cosine_similarity: 0.9890 - val_loss: 0.0171 - val_cosine_similarity: 0.9789
# Epoch 82/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0090 - cosine_similarity: 0.9892 - val_loss: 0.0169 - val_cosine_similarity: 0.9791
# Epoch 83/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0090 - cosine_similarity: 0.9892 - val_loss: 0.0171 - val_cosine_similarity: 0.9789
# Epoch 84/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0091 - cosine_similarity: 0.9890 - val_loss: 0.0171 - val_cosine_similarity: 0.9789
# Epoch 85/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0088 - cosine_similarity: 0.9894 - val_loss: 0.0168 - val_cosine_similarity: 0.9792
# Epoch 86/200
# 344/344 [==============================] - 17s 49ms/step - loss: 0.0087 - cosine_similarity: 0.9895 - val_loss: 0.0166 - val_cosine_similarity: 0.9794
# Epoch 87/200
# 344/344 [==============================] - 17s 50ms/step - loss: 0.0087 - cosine_similarity: 0.9896 - val_loss: 0.0166 - val_cosine_similarity: 0.9795
# Epoch 88/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0086 - cosine_similarity: 0.9896 - val_loss: 0.0169 - val_cosine_similarity: 0.9791
# Epoch 89/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0083 - cosine_similarity: 0.9900 - val_loss: 0.0172 - val_cosine_similarity: 0.9789
# Epoch 90/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0085 - cosine_similarity: 0.9897 - val_loss: 0.0176 - val_cosine_similarity: 0.9784
# Epoch 91/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0085 - cosine_similarity: 0.9898 - val_loss: 0.0169 - val_cosine_similarity: 0.9792
# Epoch 92/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0084 - cosine_similarity: 0.9899 - val_loss: 0.0174 - val_cosine_similarity: 0.9786
# Epoch 93/200
# 344/344 [==============================] - 17s 51ms/step - loss: 0.0085 - cosine_similarity: 0.9897 - val_loss: 0.0171 - val_cosine_similarity: 0.9789
# Epoch 94/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0086 - cosine_similarity: 0.9896 - val_loss: 0.0171 - val_cosine_similarity: 0.9790
# Epoch 95/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0086 - cosine_similarity: 0.9897 - val_loss: 0.0169 - val_cosine_similarity: 0.9793
# Epoch 96/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0085 - cosine_similarity: 0.9898 - val_loss: 0.0169 - val_cosine_similarity: 0.9793
# Epoch 97/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0083 - cosine_similarity: 0.9900 - val_loss: 0.0177 - val_cosine_similarity: 0.9781
# Epoch 98/200
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0083 - cosine_similarity: 0.9900 - val_loss: 0.0176 - val_cosine_similarity: 0.9782
# Epoch 99/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0080 - cosine_similarity: 0.9903 - val_loss: 0.0170 - val_cosine_similarity: 0.9791
# Epoch 100/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0081 - cosine_similarity: 0.9903 - val_loss: 0.0170 - val_cosine_similarity: 0.9790
# Epoch 101/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0080 - cosine_similarity: 0.9903 - val_loss: 0.0168 - val_cosine_similarity: 0.9795
# Epoch 102/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0080 - cosine_similarity: 0.9904 - val_loss: 0.0170 - val_cosine_similarity: 0.9792
# Epoch 103/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0081 - cosine_similarity: 0.9902 - val_loss: 0.0170 - val_cosine_similarity: 0.9791
# Epoch 104/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0082 - cosine_similarity: 0.9901 - val_loss: 0.0168 - val_cosine_similarity: 0.9792
# Epoch 105/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0083 - cosine_similarity: 0.9900 - val_loss: 0.0169 - val_cosine_similarity: 0.9792
# Epoch 106/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0081 - cosine_similarity: 0.9903 - val_loss: 0.0167 - val_cosine_similarity: 0.9794
# Epoch 107/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0081 - cosine_similarity: 0.9902 - val_loss: 0.0161 - val_cosine_similarity: 0.9801
# Epoch 108/200
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0079 - cosine_similarity: 0.9905 - val_loss: 0.0165 - val_cosine_similarity: 0.9796
# Epoch 109/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0077 - cosine_similarity: 0.9907 - val_loss: 0.0163 - val_cosine_similarity: 0.9798
# Epoch 110/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0077 - cosine_similarity: 0.9908 - val_loss: 0.0160 - val_cosine_similarity: 0.9803
# Epoch 111/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0075 - cosine_similarity: 0.9909 - val_loss: 0.0161 - val_cosine_similarity: 0.9802
# Epoch 112/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0074 - cosine_similarity: 0.9911 - val_loss: 0.0158 - val_cosine_similarity: 0.9806
# Epoch 113/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0160 - val_cosine_similarity: 0.9803
# Epoch 114/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9913 - val_loss: 0.0162 - val_cosine_similarity: 0.9802
# Epoch 115/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9913 - val_loss: 0.0161 - val_cosine_similarity: 0.9803
# Epoch 116/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9915 - val_loss: 0.0161 - val_cosine_similarity: 0.9800
# Epoch 117/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9914 - val_loss: 0.0160 - val_cosine_similarity: 0.9802
# Epoch 118/200
# 344/344 [==============================] - 17s 50ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0163 - val_cosine_similarity: 0.9800
# Epoch 119/200
# 344/344 [==============================] - 17s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9913 - val_loss: 0.0159 - val_cosine_similarity: 0.9807
# Epoch 120/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0162 - val_cosine_similarity: 0.9802
# Epoch 121/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0161 - val_cosine_similarity: 0.9802
# Epoch 122/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0162 - val_cosine_similarity: 0.9800
# Epoch 123/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9915 - val_loss: 0.0159 - val_cosine_similarity: 0.9805
# Epoch 124/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9912 - val_loss: 0.0156 - val_cosine_similarity: 0.9808
# Epoch 125/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9915 - val_loss: 0.0152 - val_cosine_similarity: 0.9812
# Epoch 126/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9916 - val_loss: 0.0153 - val_cosine_similarity: 0.9811
# Epoch 127/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9916 - val_loss: 0.0163 - val_cosine_similarity: 0.9800
# Epoch 128/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9914 - val_loss: 0.0165 - val_cosine_similarity: 0.9796
# Epoch 129/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9913 - val_loss: 0.0160 - val_cosine_similarity: 0.9802
# Epoch 130/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9914 - val_loss: 0.0158 - val_cosine_similarity: 0.9805
# Epoch 131/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9914 - val_loss: 0.0158 - val_cosine_similarity: 0.9805
# Epoch 132/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9915 - val_loss: 0.0160 - val_cosine_similarity: 0.9802
# Epoch 133/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0072 - cosine_similarity: 0.9913 - val_loss: 0.0157 - val_cosine_similarity: 0.9805
# Epoch 134/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9915 - val_loss: 0.0153 - val_cosine_similarity: 0.9811
# Epoch 135/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9915 - val_loss: 0.0152 - val_cosine_similarity: 0.9812
# Epoch 136/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9917 - val_loss: 0.0148 - val_cosine_similarity: 0.9816
# Epoch 137/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0067 - cosine_similarity: 0.9919 - val_loss: 0.0149 - val_cosine_similarity: 0.9817
# Epoch 138/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9918 - val_loss: 0.0154 - val_cosine_similarity: 0.9811
# Epoch 139/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9916 - val_loss: 0.0154 - val_cosine_similarity: 0.9811
# Epoch 140/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9916 - val_loss: 0.0154 - val_cosine_similarity: 0.9810
# Epoch 141/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0073 - cosine_similarity: 0.9913 - val_loss: 0.0152 - val_cosine_similarity: 0.9812
# Epoch 142/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9915 - val_loss: 0.0150 - val_cosine_similarity: 0.9816
# Epoch 143/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9917 - val_loss: 0.0154 - val_cosine_similarity: 0.9808
# Epoch 144/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9917 - val_loss: 0.0155 - val_cosine_similarity: 0.9809
# Epoch 145/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0067 - cosine_similarity: 0.9919 - val_loss: 0.0155 - val_cosine_similarity: 0.9808
# Epoch 146/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9917 - val_loss: 0.0158 - val_cosine_similarity: 0.9805
# Epoch 147/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9918 - val_loss: 0.0150 - val_cosine_similarity: 0.9815
# Epoch 148/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9918 - val_loss: 0.0152 - val_cosine_similarity: 0.9813
# Epoch 149/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9918 - val_loss: 0.0152 - val_cosine_similarity: 0.9813
# Epoch 150/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9917 - val_loss: 0.0156 - val_cosine_similarity: 0.9808
# Epoch 151/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0071 - cosine_similarity: 0.9915 - val_loss: 0.0152 - val_cosine_similarity: 0.9813
# Epoch 152/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0070 - cosine_similarity: 0.9916 - val_loss: 0.0151 - val_cosine_similarity: 0.9814
# Epoch 153/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9918 - val_loss: 0.0153 - val_cosine_similarity: 0.9811
# Epoch 154/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0068 - cosine_similarity: 0.9918 - val_loss: 0.0149 - val_cosine_similarity: 0.9816
# Epoch 155/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0069 - cosine_similarity: 0.9917 - val_loss: 0.0149 - val_cosine_similarity: 0.9817
# Epoch 156/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0065 - cosine_similarity: 0.9921 - val_loss: 0.0153 - val_cosine_similarity: 0.9812
# Epoch 157/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0066 - cosine_similarity: 0.9921 - val_loss: 0.0153 - val_cosine_similarity: 0.9811
# Epoch 158/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0066 - cosine_similarity: 0.9921 - val_loss: 0.0151 - val_cosine_similarity: 0.9814
# Epoch 159/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0065 - cosine_similarity: 0.9922 - val_loss: 0.0147 - val_cosine_similarity: 0.9817
# Epoch 160/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0064 - cosine_similarity: 0.9923 - val_loss: 0.0145 - val_cosine_similarity: 0.9820
# Epoch 161/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0064 - cosine_similarity: 0.9924 - val_loss: 0.0145 - val_cosine_similarity: 0.9819
# Epoch 162/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0064 - cosine_similarity: 0.9924 - val_loss: 0.0147 - val_cosine_similarity: 0.9819
# Epoch 163/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0065 - cosine_similarity: 0.9922 - val_loss: 0.0146 - val_cosine_similarity: 0.9819
# Epoch 164/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0064 - cosine_similarity: 0.9923 - val_loss: 0.0146 - val_cosine_similarity: 0.9820
# Epoch 165/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0063 - cosine_similarity: 0.9925 - val_loss: 0.0148 - val_cosine_similarity: 0.9817
# Epoch 166/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0061 - cosine_similarity: 0.9926 - val_loss: 0.0152 - val_cosine_similarity: 0.9814
# Epoch 167/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0063 - cosine_similarity: 0.9924 - val_loss: 0.0157 - val_cosine_similarity: 0.9807
# Epoch 168/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0063 - cosine_similarity: 0.9924 - val_loss: 0.0163 - val_cosine_similarity: 0.9797
# Epoch 169/200
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0062 - cosine_similarity: 0.9925 - val_loss: 0.0163 - val_cosine_similarity: 0.9798
# Epoch 170/200
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0063 - cosine_similarity: 0.9924 - val_loss: 0.0158 - val_cosine_similarity: 0.9804
# Epoch 171/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9926 - val_loss: 0.0158 - val_cosine_similarity: 0.9804
# Epoch 172/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9926 - val_loss: 0.0152 - val_cosine_similarity: 0.9813
# Epoch 173/200
# 344/344 [==============================] - 18s 52ms/step - loss: 0.0061 - cosine_similarity: 0.9927 - val_loss: 0.0149 - val_cosine_similarity: 0.9816
# Epoch 174/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0060 - cosine_similarity: 0.9928 - val_loss: 0.0148 - val_cosine_similarity: 0.9818
# Epoch 175/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0061 - cosine_similarity: 0.9927 - val_loss: 0.0148 - val_cosine_similarity: 0.9818
# Epoch 176/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0061 - cosine_similarity: 0.9927 - val_loss: 0.0147 - val_cosine_similarity: 0.9819
# Epoch 177/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0061 - cosine_similarity: 0.9927 - val_loss: 0.0152 - val_cosine_similarity: 0.9814
# Epoch 178/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0061 - cosine_similarity: 0.9927 - val_loss: 0.0156 - val_cosine_similarity: 0.9806
# Epoch 179/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9925 - val_loss: 0.0153 - val_cosine_similarity: 0.9810
# Epoch 180/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9925 - val_loss: 0.0151 - val_cosine_similarity: 0.9812
# Epoch 181/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9925 - val_loss: 0.0154 - val_cosine_similarity: 0.9808
# Epoch 182/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0063 - cosine_similarity: 0.9925 - val_loss: 0.0150 - val_cosine_similarity: 0.9815
# Epoch 183/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9925 - val_loss: 0.0150 - val_cosine_similarity: 0.9815
# Epoch 184/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0063 - cosine_similarity: 0.9924 - val_loss: 0.0156 - val_cosine_similarity: 0.9808
# Epoch 185/200
# 344/344 [==============================] - 17s 50ms/step - loss: 0.0064 - cosine_similarity: 0.9923 - val_loss: 0.0154 - val_cosine_similarity: 0.9809
# Epoch 186/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0062 - cosine_similarity: 0.9926 - val_loss: 0.0152 - val_cosine_similarity: 0.9811
# Epoch 187/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0060 - cosine_similarity: 0.9927 - val_loss: 0.0152 - val_cosine_similarity: 0.9812
# Epoch 188/200
# 344/344 [==============================] - 17s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0149 - val_cosine_similarity: 0.9816
# Epoch 189/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9930 - val_loss: 0.0145 - val_cosine_similarity: 0.9820
# Epoch 190/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0151 - val_cosine_similarity: 0.9812
# Epoch 191/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0060 - cosine_similarity: 0.9928 - val_loss: 0.0147 - val_cosine_similarity: 0.9817
# Epoch 192/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0144 - val_cosine_similarity: 0.9822
# Epoch 193/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0143 - val_cosine_similarity: 0.9822
# Epoch 194/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9930 - val_loss: 0.0142 - val_cosine_similarity: 0.9824
# Epoch 195/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0060 - cosine_similarity: 0.9928 - val_loss: 0.0140 - val_cosine_similarity: 0.9824
# Epoch 196/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0142 - val_cosine_similarity: 0.9823
# Epoch 197/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0059 - cosine_similarity: 0.9929 - val_loss: 0.0144 - val_cosine_similarity: 0.9822
# Epoch 198/200
# 344/344 [==============================] - 17s 51ms/step - loss: 0.0058 - cosine_similarity: 0.9930 - val_loss: 0.0147 - val_cosine_similarity: 0.9816
# Epoch 199/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0058 - cosine_similarity: 0.9931 - val_loss: 0.0144 - val_cosine_similarity: 0.9821
# Epoch 200/200
# 344/344 [==============================] - 18s 51ms/step - loss: 0.0058 - cosine_similarity: 0.9931 - val_loss: 0.0148 - val_cosine_similarity: 0.9817

# %% [markdown]
# ## Evaluate the model

# %%
result = model.evaluate(
    x=test_data,
    return_dict=True
)
# Out:
# 43/43 [==============================] - 1s 16ms/step - loss: 0.0139 - cosine_similarity: 0.9830

# %%
for name, val in result.items():
    print("{:20s} {:.4f}".format(name, val))
# Out:
# loss                 0.0139
# cosine_similarity    0.9830

# %% [markdown]
# ## Save the model

# %%
model.save(SAVE_LOC)
# Out:
# INFO:tensorflow:Assets written to: ./data/models/cnn_1_20210914-125805/assets
